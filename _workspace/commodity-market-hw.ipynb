# %%
import os
import numpy as np
import pandas as pd
from IPython.display import display, Markdown, Latex

import econtools
from econtools.documents import Homework, RawLatex
import utils2 as u2

OUTPUT_DIR = "./tex"
TITLE = "Commodity Market Problem Set"
FILENAME = "commodity-market-hw"

doc = Homework(
    title = TITLE,
)
rng = np.random.default_rng(103)

# %%
tex = fr"""
\begin{{q}}
Review, memorize, and be able to explain the ``big picture review'' section for this lecture.
\end{{q}}
"""
doc.add(RawLatex(tex))

# %%
tex = fr"""
\begin{{q}}
If the consumer's utility for the commodity increases, what do you expect to happen to the equilibrium price and quantity traded in the market?
\end{{q}}
"""
doc.add(RawLatex(tex))

# %%
tex = fr"""
\begin{{q}}
If the firm's cost function for producing the commodity increases, what do you expect to happen to the equilibrium price and quantity traded in the market?
\end{{q}}
"""
doc.add(RawLatex(tex))

# %%
TYPE = 'LinearCommodityMarketProblem'
df = pd.read_csv(f"{TYPE}.csv")
params = dict(df.sample(1,random_state=rng).iloc[0])
problem = u2.load_problem(TYPE, params, rng=rng)
doc.add(u2.get_multipart_sa(problem,setup_id=0,question_ids=[0,1,2,3,4,5]))
print(problem.sol)
# Out:
# {'q': np.float64(0.8), 'p': np.float64(13.4), 'U': np.float64(0.6399999999999988), 'profit': np.float64(0.9599999999999997)}

# %%
TYPE = 'ExponentialCommodityMarketProblem'
df = pd.read_csv(f"{TYPE}.csv")
params = dict(df.sample(1,random_state=rng).iloc[0])
problem = u2.load_problem(TYPE, params, rng=rng)
doc.add(u2.get_multipart_sa(problem,setup_id=0,question_ids=[0,1,2,3,4,5]))
print(problem.sol)
# Out:
# {'q': np.float64(3.0), 'p': np.float64(3.0), 'U': np.float64(0.8875105980129874), 'profit': np.float64(4.5)}

# %%
doc.print_pdf(FILENAME, OUTPUT_DIR)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.29 (MiKTeX 26.1) (preloaded format=pdflatex.fmt)
#  restricted \write18 enabled.
# entering extended mode
# (commodity-market-hw.tex
# LaTeX2e <2025-11-01>
# L3 programming layer <2026-01-19>
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/base\article.cls
# Document Class: article 2025/01/22 v1.4n Standard LaTeX document class
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/base\size11.clo))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/base\inputenc.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/graphics\keyval.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/iftex\ifvtex.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/iftex\iftex.sty))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/geometry\geometry.cfg))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgfplots\pgfplots.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.rev
# ision.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/graphics\graphicx.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/graphics\graphics.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/graphics\trig.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/graphics-cfg\graphics.c
# fg)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/graphics-def\pdftex.def
# )))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgf/frontendlayer\tikz.
# sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgf/basiclayer\pgf.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgf/utilities\pgfrcs.st
# y
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfutil
# -common.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfutil
# -latex.def)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfrcs.
# code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf\pgf.revision.tex)
# ))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgf/basiclayer\pgfcore.
# sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgf/systemlayer\pgfsys.
# sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgfsy
# s.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfkeys
# .code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfkeys
# libraryfiltered.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgf.c
# fg)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgfsy
# s-pdftex.def
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgfsy
# s-common-pdf.def)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgfsy
# ssoftpath.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/systemlayer\pgfsy
# sprotocol.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/xcolor\xcolor.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/graphics-cfg\color.cfg)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/graphics\mathcolor.ltx)
# )
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# e.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmath.code
# .tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathutil.
# code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathparse
# r.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfunct
# ions.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfunct
# ions.basic.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfunct
# ions.trigonometric.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfunct
# ions.random.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfunct
# ions.comparison.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfunct
# ions.base.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfunct
# ions.round.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfunct
# ions.misc.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfunct
# ions.integerarithmetics.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathcalc.
# code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmathfloat
# .code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfint.code.
# tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# epoints.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# epathconstruct.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# epathusage.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# escopes.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# egraphicstate.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# etransformations.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# equick.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# eobjects.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# epathprocessing.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# earrows.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# eshade.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# eimage.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# eexternal.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# elayers.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# etransparency.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# epatterns.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/basiclayer\pgfcor
# erdf.code.tex)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/modules\pgfmodule
# shapes.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/modules\pgfmodule
# plot.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgf/compatibility\pgfco
# mp-version-0-65.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgf/compatibility\pgfco
# mp-version-1-18.sty))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgf/utilities\pgffor.st
# y
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgf/utilities\pgfkeys.s
# ty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgfkeys
# .code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/pgf/math\pgfmath.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/math\pgfmath.code
# .tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/utilities\pgffor.
# code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z\tikz.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgflibr
# aryplothandlers.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/modules\pgfmodule
# matrix.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z/libraries\tikzlibrarytopaths.code.tex)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.cod
# e.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotscore
# .code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/sys\pgfplots
# sysgeneric.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/libs\pgfplot
# slibrary.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/oldpgfcompat
# ib\pgfplotsoldpgfsupp_loader.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgflibr
# aryfpu.code.tex)
# Package pgfplots: loading complementary utilities for your pgf version...
#
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/oldpgfcompat
# ib\pgfplotsoldpgfsupp_pgfutil-common-lists.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfplot
# sutil.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/liststructur
# e\pgfplotsliststructure.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/liststructur
# e\pgfplotsliststructureext.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/liststructur
# e\pgfplotsarray.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/liststructur
# e\pgfplotsmatrix.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/numtable\pgf
# plotstableshared.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/liststructur
# e\pgfplotsdeque.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfplot
# sbinary.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfplot
# sbinary.data.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfplot
# sutil.verb.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/libs\pgflibr
# arypgfplots.surfshading.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/sys\pgflibra
# rypgfplots.surfshading.pgfsys-pdftex.def)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfplot
# scolormap.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/util\pgfplot
# scolor.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotsstac
# kedplots.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotsplot
# handlers.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotsmesh
# plothandler.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotsmesh
# plotimage.code.tex)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.sca
# ling.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotscoor
# dprocessing.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.err
# orbars.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.mar
# kers.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplotstick
# s.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots\pgfplots.pat
# hs.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z/libraries\tikzlibrarydecorations.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/modules\pgfmodule
# decorations.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z/libraries\tikzlibrarydecorations.pathmorphing.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/decorat
# ions\pgflibrarydecorations.pathmorphing.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z/libraries\tikzlibrarydecorations.pathreplacing.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/decorat
# ions\pgflibrarydecorations.pathreplacing.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/libs\tikzlib
# rarypgfplots.contourlua.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z/libraries\tikzlibraryplotmarks.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgflibr
# aryplotmarks.code.tex)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/libs\tikzlib
# rarypgfplots.fillbetween.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/pgfcontrib\t
# ikzlibraryfillbetween.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z/libraries\tikzlibraryintersections.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgflibr
# aryintersections.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/pgfcontrib\t
# ikzlibrarydecorations.softclip.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/pgfcontrib\p
# gflibraryfillbetween.code.tex)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgfplots/libs\tikzlib
# rarypgfplots.decorations.softclip.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z/libraries\tikzlibrarypatterns.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgflibr
# arypatterns.code.tex))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries\pgflibr
# aryarrows.meta.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z/libraries\tikzlibrarypositioning.code.tex)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z/libraries\tikzlibraryautomata.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/frontendlayer/tik
# z/libraries\tikzlibraryshapes.multipart.code.tex
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pgf/libraries/shapes\
# pgflibraryshapes.multipart.code.tex)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsmath.sty
# For additional information on amsmath, use the `?' option.
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amstext.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsgen.sty))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsbsy.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/amsmath\amsopn.sty))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/tools\enumerate.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/setspace\setspace.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/tools\array.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/multirow\multirow.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/tools\tabularx.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/booktabs\booktabs.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/l3packages/xfp\xfp.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/l3kernel\expl3.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/l3backend\l3backend-pdf
# tex.def)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/enumitem\enumitem.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/parskip\parskip.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/kvoptions\kvoptions.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/ltxcmds\ltxcmds.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/kvsetkeys\kvsetkeys.sty
# ))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/etoolbox\etoolbox.sty))
#  (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/psnfss\pifont.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/psnfss\upzd.fd)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/psnfss\upsy.fd))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/wasysym\wasysym.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/amsfonts\amssymb.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/amsfonts\amsfonts.sty))
#  (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/hyperref\hyperref.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/kvdefinekeys\kvdefine
# keys.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pdfescape\pdfescape.s
# ty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/pdftexcmds\pdftexcmds
# .sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/infwarerr\infwarerr.s
# ty)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/hycolor\hycolor.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/hyperref\nameref.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/refcount\refcount.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/gettitlestring\gettit
# lestring.sty))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/stringenc\stringenc.s
# ty) (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/hyperref\pd1enc.def
# ) (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/intcalc\intcalc.sty
# ) (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/hyperref\puenc.def)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/url\url.sty)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/bitset\bitset.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/bigintcalc\bigintcalc
# .sty)))
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/hyperref\hpdftex.def
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/rerunfilecheck\rerunfil
# echeck.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/base\atveryend-ltx.sty)
#
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/generic/uniquecounter\uniquec
# ounter.sty))) (commodity-market-hw.aux)
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
#
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/context/base/mkii\supp-pdf.mk
# ii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/epstopdf-pkg\epstopdf-b
# ase.sty
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/00miktex\epstopdf-sys.c
# fg))
# Package pgfplots notification 'compat/show suggested version=true': you might b
# enefit from \pgfplotsset{compat=1.18} (current compat level: 1.11).
#
# (commodity-market-hw.out) (commodity-market-hw.out)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/wasysym\uwasy.fd)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/amsfonts\umsa.fd)
# (C:\Users\ekung\AppData\Local\Programs\MiKTeX\tex/latex/amsfonts\umsb.fd)
# Overfull \hbox (30.0pt too wide) in paragraph at lines 45--49
# []$[]$
#
# Overfull \hbox (30.0pt too wide) in paragraph at lines 50--58
# []$[]$
#
# Overfull \hbox (30.0pt too wide) in paragraph at lines 59--67
# []$[]$
#
# Overfull \hbox (30.0pt too wide) in paragraph at lines 68--76
# []$[]$
#
# Overfull \hbox (30.0pt too wide) in paragraph at lines 77--103
# []$[]$
#
# Overfull \hbox (30.0pt too wide) in paragraph at lines 104--130
# []$[]$
# [1{C:/Users/ekung/AppData/Local/MiKTeX/fonts/map/pdftex/pdftex.map}] [2]
# (commodity-market-hw.aux) )
# (see the transcript file for additional information)<C:/Users/ekung/AppData/Loc
# al/Programs/MiKTeX/fonts/type1/public/amsfonts/cm/cmmi10.pfb><C:/Users/ekung/Ap
# pData/Local/Programs/MiKTeX/fonts/type1/public/amsfonts/cm/cmr10.pfb><C:/Users/
# ekung/AppData/Local/Programs/MiKTeX/fonts/type1/public/amsfonts/cm/cmr8.pfb><C:
# /Users/ekung/AppData/Local/Programs/MiKTeX/fonts/type1/public/amsfonts/cm/cmsy1
# 0.pfb>
# Output written on commodity-market-hw.pdf (2 pages, 54459 bytes).
# Transcript written on commodity-market-hw.log.
