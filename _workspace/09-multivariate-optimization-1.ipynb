# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm

SMALL_SIZE = 14
MEDIUM_SIZE = 16
LARGE_SIZE = 18

plt.rcdefaults()
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'Helvetica'
plt.rcParams['font.size'] = MEDIUM_SIZE
plt.rcParams['axes.titlesize'] = LARGE_SIZE
plt.rcParams['axes.labelsize'] = MEDIUM_SIZE
plt.rcParams['xtick.labelsize'] = MEDIUM_SIZE
plt.rcParams['ytick.labelsize'] = MEDIUM_SIZE
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE
plt.rcParams['figure.titlesize'] = LARGE_SIZE
plt.rcParams['figure.figsize'] = [7.2, 7.2]
plt.rcParams['figure.dpi'] = 60
plt.rcParams['figure.facecolor'] = (1.0, 1.0, 1.0, 0.0)

from utils import SREQ, LREQ

# %%
x = np.arange(0, 8.1,0.1)
y = np.arange(0, 8.1,0.1)
x, y = np.meshgrid(x,y)
z = x*(8-x) + y*(8-y)

fig, ax = plt.subplots(subplot_kw={'projection': '3d'})
ax.plot_surface(x,y,z,cmap=cm.coolwarm)
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')
ax.set_zlabel(r'$z$')
plt.savefig('../assets/images/09-multivariate-optimization-1-surface-1.png', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots()
CS = ax.contour(x,y,z,levels=np.arange(20,32,2), cmap=cm.coolwarm)
ax.clabel(CS, CS.levels, inline=True, fontsize=MEDIUM_SIZE)
ax.plot(4,4,'^',color='black')
ax.text(4.125,4,r'$32$',fontsize=MEDIUM_SIZE)
ax.set_ylabel(r'$y$')
ax.set_xlabel(r'$x$')
ax.set_axisbelow(True)
plt.grid(alpha=0.2)
plt.savefig('../assets/images/09-multivariate-optimization-1-contour-1.png', bbox_inches='tight')
plt.show()

# %%
x = np.arange(0, 9.1,0.1)
y = np.arange(0, 9.1,0.1)
x, y = np.meshgrid(x,y)
z = x**0.5 * y**0.5

fig, ax = plt.subplots(subplot_kw={'projection': '3d'})
ax.plot_surface(x,y,z,cmap=cm.coolwarm)
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')
ax.set_zlabel(r'$z$')
plt.savefig('../assets/images/09-multivariate-optimization-1-surface-2.png', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots()
CS = ax.contour(x,y,z, levels=np.arange(2,8), cmap=cm.coolwarm)
ax.clabel(CS, CS.levels, inline=True, fontsize=MEDIUM_SIZE)
#ax.plot(4,4,'^',color='black')
#ax.text(4.125,4,r'$32$',fontsize=MEDIUM_SIZE)
ax.set_ylabel(r'$y$')
ax.set_xlabel(r'$x$')
ax.set_axisbelow(True)
plt.grid(alpha=0.2)
plt.savefig('../assets/images/09-multivariate-optimization-1-contour-2.png', bbox_inches='tight')
plt.show()

# %%
x = np.arange(0, 8.1,0.1)
y = np.arange(0, 8.1,0.1)
x, y = np.meshgrid(x,y)
z = x*(8-x) + y*(8-y)

fig, ax = plt.subplots()
CS = ax.contour(x,y,z,levels=np.arange(20,32,2), cmap=cm.coolwarm)
ax.clabel(CS, CS.levels, inline=True, fontsize=MEDIUM_SIZE)
ax.plot(4,4,'^',color='black')
ax.text(4.125,4,r'$32$',fontsize=MEDIUM_SIZE)
ax.plot([0,8], [6,6], color='black')
ax.set_ylabel(r'$y$')
ax.set_xlabel(r'$x$')
ax.set_axisbelow(True)
plt.grid(alpha=0.2)
plt.savefig('../assets/images/09-multivariate-optimization-1-partial-x-contour.png', bbox_inches='tight')
plt.show()

x = np.arange(0, 8.1, 0.1)
y = 6
z = x*(8-x) + y*(8-y)
plt.figure(figsize=(7.2,4.8))
plt.plot(x, z)
plt.xlabel(r'$x$')
plt.ylabel(r'$f(x,6)$')
plt.title(r'$f(x,6)$')
plt.gca().set_axisbelow(True)
plt.grid(alpha=0.2)
plt.ylim(0,35)
plt.savefig('../assets/images/09-multivariate-optimization-1-partial-x-slice.png', bbox_inches='tight')
plt.show()

x = np.arange(0, 8.1, 0.1)
y = 6
z = 8 - 2*x
plt.figure(figsize=(7.2,4.8))
plt.plot(x, z)
plt.xlabel(r'$x$')
plt.ylabel(r'$f_x(x,6)$')
plt.title(r'$f_x(x,6)$')
plt.gca().set_axisbelow(True)
plt.grid(alpha=0.2)
plt.savefig('../assets/images/09-multivariate-optimization-1-partial-x-deriv.png', bbox_inches='tight')
plt.show()

# %%
x = np.arange(0, 8.1,0.1)
y = np.arange(0, 8.1,0.1)
x, y = np.meshgrid(x,y)
z = x*(8-x) + y*(8-y)

fig, ax = plt.subplots()
CS = ax.contour(x,y,z,levels=np.arange(20,32,2), cmap=cm.coolwarm)
ax.clabel(CS, CS.levels, inline=True, fontsize=MEDIUM_SIZE)
ax.plot(4,4,'^',color='black')
ax.text(4.125,4,r'$32$',fontsize=MEDIUM_SIZE)
ax.plot([3,3], [0,8], color='black')
ax.set_ylabel(r'$y$')
ax.set_xlabel(r'$x$')
ax.set_axisbelow(True)
plt.grid(alpha=0.2)
plt.savefig('../assets/images/09-multivariate-optimization-1-partial-y-contour.png', bbox_inches='tight')
plt.show()

x = 3
y = np.arange(0,8.1,0.1)
z = x*(8-x) + y*(8-y)
plt.figure(figsize=(7.2,4.8))
plt.plot(y, z)
plt.xlabel(r'$y$')
plt.ylabel(r'$f(3,y)$')
plt.title(r'$f(3,y)$')
plt.gca().set_axisbelow(True)
plt.grid(alpha=0.2)
plt.ylim(0,35)
plt.savefig('../assets/images/09-multivariate-optimization-1-partial-y-slice.png', bbox_inches='tight')
plt.show()

x = 3
y = np.arange(0,8.1,0.1)
z = 8 - 2*y
plt.figure(figsize=(7.2,4.8))
plt.plot(y, z)
plt.xlabel(r'$y$')
plt.ylabel(r'$f_y(3,y)$')
plt.title(r'$f_y(3,y)$')
plt.gca().set_axisbelow(True)
plt.grid(alpha=0.2)
plt.savefig('../assets/images/09-multivariate-optimization-1-partial-y-deriv.png', bbox_inches='tight')
plt.show()

# %%
x = np.arange(0, 48.1,0.1)
y = np.arange(0, 24.1,0.1)
x, y = np.meshgrid(x,y)
z = 12*x + x*y - 0.5*x**2 - y**2

fig, ax = plt.subplots()
CS = ax.contour(x,y,z,levels=np.arange(0,160,20),cmap=cm.coolwarm)
ax.clabel(CS, CS.levels,inline=True, fontsize=MEDIUM_SIZE)
ax.plot(24,12,'^',color='black')
ax.text(24,12.5,r'$144$',fontsize=MEDIUM_SIZE)
ax.set_ylabel(r'$y$')
ax.set_xlabel(r'$x$')
ax.set_axisbelow(True)
plt.grid(alpha=0.2)
plt.savefig('../assets/images/09-multivariate-optimization-1-contour-3.png', bbox_inches='tight')
plt.show()

12*24 + 24*12 - 0.5*24**2 - 12**2
# Out:
# 144.0
