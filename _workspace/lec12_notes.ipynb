# %%
import os
import numpy as np
import pandas as pd
from IPython.display import display, Markdown, Latex
import json
import utils2 as u2
from matplotlib import pyplot as plt

SMALL_SIZE = 14
MEDIUM_SIZE = 16
LARGE_SIZE = 18
HUGE_SIZE = 20

plt.rcdefaults()
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'Helvetica'
plt.rcParams['font.size'] = MEDIUM_SIZE
plt.rcParams['axes.titlesize'] = LARGE_SIZE
plt.rcParams['axes.labelsize'] = MEDIUM_SIZE
plt.rcParams['xtick.labelsize'] = MEDIUM_SIZE
plt.rcParams['ytick.labelsize'] = MEDIUM_SIZE
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE
plt.rcParams['figure.titlesize'] = LARGE_SIZE
plt.rcParams['figure.figsize'] = [7.2, 7.2]
plt.rcParams['figure.dpi'] = 60
plt.rcParams['figure.facecolor'] = (1.0, 1.0, 1.0, 0.0)

PROBLEM_NAME = "lec12_example"
IMAGE_PATH = "../assets/images/graphs"
nprob = 0

rng = np.random.default_rng(112)

# %%
TYPE = "CobbDouglasWorkerProblem"
params = {'x': 20.0, 'w': 30.0, 'yunit': 200.0, 'y': 1200.0, 'I': 1800.0}
problem = u2.load_problem(TYPE, params)
print(problem.setup_list[0]['online_setup'])
problem.setup_axis.draw(saveas=fr"{IMAGE_PATH}/{PROBLEM_NAME}_{nprob}_setup.png")
problem.solution_axis.draw(saveas=fr"{IMAGE_PATH}/{PROBLEM_NAME}_{nprob}_solution.png")
nprob+=1
# Out:
# A worker has up to 60 hours a week to spend on working or on leisure. If he works, he makes a wage rate of \(w=30\) dollars per hour. The worker's
# indifference curves over leisure and income are shown in the diagram below.
# <p>
# <img src="/CSUN-Econ-310/assets/images/graphs/generic_problem_setup.png">
# </p>

# %%
TYPE = "WageChangeProblem"
params = {'w1':15,'w2':40,'x1':20,'x2':15}
problem_name = fr"{PROBLEM_NAME}_{nprob}"
problem = u2.load_problem(TYPE, params, name=problem_name)
print(problem.setup_list[0]['online_setup'])
problem.setup_axis.draw(saveas=fr"{IMAGE_PATH}/{problem_name}_setup.png")
problem.solution_axis.draw(saveas=fr"{IMAGE_PATH}/{problem_name}_solution.png")
print(nprob)
nprob+=1
# Out:
# A worker has up to 60 hours a week to spend on working or on leisure. If he works, he makes a wage rate of \(w=15\) dollars per hour. The worker's
# indifference curves over leisure and income are shown in the diagram below.
# <p>
# <img src="/CSUN-Econ-310/assets/images/graphs/lec12_example_1_setup.png">
# </p>
# One day, the worker's hourly wage changes to \(w^\prime = 40\).
#
# 1

# %%
TYPE = "WageChangeProblem"
params = {'w1':20, 'w2':60, 'x1':30, 'x2':35}
problem_name = fr"{PROBLEM_NAME}_{nprob}"
problem = u2.load_problem(TYPE, params, name=problem_name)
print(problem.setup_list[0]['online_setup'])
problem.setup_axis.draw(saveas=fr"{IMAGE_PATH}/{problem_name}_setup.png")
problem.solution_axis.draw(saveas=fr"{IMAGE_PATH}/{problem_name}_solution.png")
print(nprob)
nprob+=1
# Out:
# A worker has up to 60 hours a week to spend on working or on leisure. If he works, he makes a wage rate of \(w=20\) dollars per hour. The worker's
# indifference curves over leisure and income are shown in the diagram below.
# <p>
# <img src="/CSUN-Econ-310/assets/images/graphs/lec12_example_2_setup.png">
# </p>
# One day, the worker's hourly wage changes to \(w^\prime = 60\).
#
# 2

# %%
TYPE = "IncomeSupportProblem"
params = {'x':40, 'w':10, 'yunit':50, 'ymin':250}
problem_name = fr"{PROBLEM_NAME}_{nprob}"
problem = u2.load_problem(TYPE, params, name=problem_name)
print(problem.setup_list[0]['online_setup'])
problem.setup_axis.draw(saveas=fr"{IMAGE_PATH}/{problem_name}_setup.png")
problem.solution_axis.draw(saveas=fr"{IMAGE_PATH}/{problem_name}_solution.png")
print(nprob)
nprob+=1
# Out:
# A worker has up to 60 hours a week to spend on working or on leisure. If he works, he makes a wage rate of \(w=10\) dollars per hour. The worker's
# indifference curves over leisure and income are shown in the diagram below.
# <p>
# <img src="/CSUN-Econ-310/assets/images/graphs/lec12_example_3_setup.png">
# </p>
# In addition, the government provides minimum income support of up to \(250\) dollars a week. That is, if someone earns less than \(250\) dollars a week, the government supplements their income until it reaches \(250\) a week.
#
# 3

# %%
TYPE = "IncomeSupportProblem"
params = {'x':25, 'w':10, 'yunit':50, 'ymin':250}
problem_name = fr"{PROBLEM_NAME}_{nprob}"
problem = u2.load_problem(TYPE, params, name=problem_name)
print(problem.setup_list[0]['online_setup'])
problem.setup_axis.draw(saveas=fr"{IMAGE_PATH}/{problem_name}_setup.png")
problem.solution_axis.draw(saveas=fr"{IMAGE_PATH}/{problem_name}_solution.png")
print(nprob)
nprob+=1
# Out:
# A worker has up to 60 hours a week to spend on working or on leisure. If he works, he makes a wage rate of \(w=10\) dollars per hour. The worker's
# indifference curves over leisure and income are shown in the diagram below.
# <p>
# <img src="/CSUN-Econ-310/assets/images/graphs/lec12_example_4_setup.png">
# </p>
# In addition, the government provides minimum income support of up to \(250\) dollars a week. That is, if someone earns less than \(250\) dollars a week, the government supplements their income until it reaches \(250\) a week.
#
# 4

# %%
TYPE = "IncomeSupportProblem"
params = {'x':30, 'w':15, 'yunit':75, 'ymin':150}
problem_name = fr"{PROBLEM_NAME}_{nprob}"
problem = u2.load_problem(TYPE, params, name=problem_name)
print(problem.setup_list[0]['online_setup'])
problem.setup_axis.draw(saveas=fr"{IMAGE_PATH}/{problem_name}_setup.png")
problem.solution_axis.draw(saveas=fr"{IMAGE_PATH}/{problem_name}_solution.png")
print(nprob)
nprob+=1
# Out:
# A worker has up to 60 hours a week to spend on working or on leisure. If he works, he makes a wage rate of \(w=15\) dollars per hour. The worker's
# indifference curves over leisure and income are shown in the diagram below.
# <p>
# <img src="/CSUN-Econ-310/assets/images/graphs/lec12_example_5_setup.png">
# </p>
# In addition, the government provides minimum income support of up to \(150\) dollars a week. That is, if someone earns less than \(150\) dollars a week, the government supplements their income until it reaches \(150\) a week.
#
# 5

# %%
np.sqrt(1807 - np.sqrt(1807 + 42))
# Out:
# 42.0
