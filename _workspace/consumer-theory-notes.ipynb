# %%
import os
import numpy as np
import pandas as pd
from IPython.display import display, Markdown, Latex
import json
import utils2 as u2
from matplotlib import pyplot as plt

SMALL_SIZE = 14
MEDIUM_SIZE = 16
LARGE_SIZE = 18
HUGE_SIZE = 20

plt.rcdefaults()
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'Helvetica'
plt.rcParams['font.size'] = MEDIUM_SIZE
plt.rcParams['axes.titlesize'] = LARGE_SIZE
plt.rcParams['axes.labelsize'] = MEDIUM_SIZE
plt.rcParams['xtick.labelsize'] = MEDIUM_SIZE
plt.rcParams['ytick.labelsize'] = MEDIUM_SIZE
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE
plt.rcParams['figure.titlesize'] = LARGE_SIZE
plt.rcParams['figure.figsize'] = [7.2, 7.2]
plt.rcParams['figure.dpi'] = 60
plt.rcParams['figure.facecolor'] = (1.0, 1.0, 1.0, 0.0)

IMAGE_PATH = "../assets/images/graphs"

rng = np.random.default_rng(109)

# %%
TYPE = "CobbDouglasConsumerProblem"
params = {'a': 1/3, 'b': 2/3, 'px': 2.0, 'py': 3.0, 'I': 90.0, 'xunit': 5.0, 'yunit': 5.0, 'xn': 13.0, 'yn': 13.0}
problem = u2.load_problem(TYPE, params)
print(problem.params)
problem.setup_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-cb-setup.png")
problem.solution_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-cb-solution.png")
# Out:
# {'a': 0.3333333333333333, 'b': 0.6666666666666666, 'px': 2.0, 'py': 3.0, 'I': 90.0, 'xunit': 5.0, 'yunit': 5.0, 'xn': 13.0, 'yn': 13.0}
# (<Figure size 432x432 with 1 Axes>, <Axes: xlabel='$x$', ylabel='$y$'>)

# %%
TYPE = "CobbDouglasConsumerProblem"
params = {'a':0.5,'b':0.5,'px':1,'py':1,'I':12}
problem = u2.load_problem(TYPE, params)
print(problem.params)
problem.setup_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-cb-example.png")
# Out:
# {'a': 0.5, 'b': 0.5, 'px': 1, 'py': 1, 'I': 12, 'xunit': 1, 'yunit': 1, 'xn': 13, 'yn': 13}
# (<Figure size 432x432 with 1 Axes>, <Axes: xlabel='$x$', ylabel='$y$'>)

# %%
TYPE = "PerfectSubstitutesProblem"
params = {'a': 1.0, 'b': 1.0, 'px': 3.0, 'py': 2.0, 'I': 120.0, 'xunit': 5.0, 'yunit': 5.0, 'xn': 13.0, 'yn': 13.0}
problem = u2.load_problem(TYPE, params)
print(problem.params)
problem.setup_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-subs-setup.png")
problem.solution_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-subs-solution.png")
# Out:
# {'a': 1.0, 'b': 1.0, 'px': 3.0, 'py': 2.0, 'I': 120.0, 'xunit': 5.0, 'yunit': 5.0, 'xn': 13.0, 'yn': 13.0}
# (<Figure size 432x432 with 1 Axes>, <Axes: xlabel='$x$', ylabel='$y$'>)

# %%
TYPE = "PerfectComplementsProblem"
params = {'px': 4.0, 'py': 2.0, 'I': 24.0, 'xunit': 1.0, 'yunit': 1.0, 'xn': 13.0, 'yn': 13.0}
problem = u2.load_problem(TYPE, params)
print(problem.params)
problem.setup_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-leontieff-setup.png")
problem.solution_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-leontieff-solution.png")
# Out:
# {'px': 4.0, 'py': 2.0, 'I': 24.0, 'xunit': 1.0, 'yunit': 1.0, 'xn': 13.0, 'yn': 13.0}
# (<Figure size 432x432 with 1 Axes>, <Axes: xlabel='$x$', ylabel='$y$'>)

# %%
TYPE = "PerfectComplementsProblem"
u2.show_menu(TYPE)
# Out:
# {'px': 1, 'py': 1, 'I': 12, 'xunit': 1, 'yunit': 1, 'xn': 13, 'yn': 13}
# {'x': 6.0, 'y': 6.0, 'U': 6.0}
# 0:  A consumer with income \(I = 12\) has a utility function over two goods, \(x\) and \(y\), represented by the indifference curves shown below. \begin{center} \includegraphics[width=3in]{generic_problem_setup.png} \end{center} The price of good \(x\) is \(p_x = 1\) and the price of good \(y\) is \(p_y = 1\).
#
# 0: Draw the consumer's budget constraint and label the optimal point A.
#
# 1: What is the consumer's optimal choice of \(x\)?
#
# 2: What is the consumer's optimal choice of \(y\)?
#
# 3: What best describes the relationship between goods \(x\) and \(y\)?
