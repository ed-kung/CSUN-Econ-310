# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm
from IPython.display import display, Markdown, Latex
import pickle

SMALL_SIZE = 14
MEDIUM_SIZE = 16
LARGE_SIZE = 18
HUGE_SIZE = 20

plt.plot()

plt.rcdefaults()
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'Helvetica'
plt.rcParams['font.size'] = MEDIUM_SIZE
plt.rcParams['axes.titlesize'] = LARGE_SIZE
plt.rcParams['axes.labelsize'] = MEDIUM_SIZE
plt.rcParams['xtick.labelsize'] = MEDIUM_SIZE
plt.rcParams['ytick.labelsize'] = MEDIUM_SIZE
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE
plt.rcParams['figure.titlesize'] = LARGE_SIZE
plt.rcParams['figure.figsize'] = [7.2, 7.2]
plt.rcParams['figure.dpi'] = 60
plt.rcParams['figure.facecolor'] = (1.0, 1.0, 1.0, 0.0)


from utils import LeisureExpPos, get_random_prob

# %%
prob = LeisureExpPos()

# %%
display(Latex(prob.general_setup()))
# Out:
# An individual can work for up to 60 hours a week at an hourly wage of \(w\). The person has utility over weekly consumption \(c\) and weekly leisure hours \(\ell\) given by:
#
# $$ u(c, \ell) = c + a \ell^k $$
#
# The general solution is:
#
# $$ \ell = \left( \frac{w}{ak} \right)^{\frac{1}{k-1} } $$

# %%
display(Latex(prob.setup()))
prob.graph_with_IC(show=True, with_solution=True)
prob.sol
# Out:
# An individual can work for up to 60 hours a week at an hourly wage of \(w=30\). The person has utility over weekly consumption \(c\) and weekly leisure hours \(\ell\) given by:
#
# $$ u(c, \ell) = c + 270\ell^{ 1 / 2 } $$
# {'c': 1192.5, 'l': 20.250000000000004, 'h': 39.75, 'U': 2407.5}

# %%
examples = []
n_found = 0
for w in np.arange(15,80,5):
    for cmax in np.array([60,90,120,150,180,210,240])*w:
        for kd in np.arange(2,5):
            for kn in np.arange(1,kd):
                for l in np.arange(10,55,5):
                    k = kn/kd
                    a = w/(k*l**(k-1))
                    params = {'a':a,'kn':kn,'kd':kd,'w':w,'cmax':cmax}
                    prob = LeisureExpPos(params)
                    if prob.check_solution():
                        n_found+=1
                        examples.append( prob.params | prob.sol )
                        if (n_found%1000==0):
                            print(f"{n_found} examples found...")
examples = pd.DataFrame.from_dict(examples)
examples = examples.drop_duplicates()
examples.to_csv("LeisureExpPos_examples.csv", index=False, header=True)
print(f"{len(examples)} examples found.")
# Out:
# 1000 examples found...
# 1590 examples found.

# %%
prob = get_random_prob(LeisureExpPos, "LeisureExpPos_examples.csv")
display(Latex(prob.setup()))
prob.graph_with_IC(show=True, with_solution=True)
# Out:
# An individual can work for up to 60 hours a week at an hourly wage of \(w=45\). The person has utility over weekly consumption \(c\) and weekly leisure hours \(\ell\) given by:
#
# $$ u(c, \ell) = c + 492.95\ell^{ 1 / 2 } $$
# True

# %%
30/(0.5*20**-0.5)
# Out:
# 268.32815729997475
