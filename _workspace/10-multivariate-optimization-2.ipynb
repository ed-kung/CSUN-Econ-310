# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm

SMALL_SIZE = 14
MEDIUM_SIZE = 16
LARGE_SIZE = 18

plt.rcdefaults()
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'Helvetica'
plt.rcParams['font.size'] = MEDIUM_SIZE
plt.rcParams['axes.titlesize'] = LARGE_SIZE
plt.rcParams['axes.labelsize'] = MEDIUM_SIZE
plt.rcParams['xtick.labelsize'] = MEDIUM_SIZE
plt.rcParams['ytick.labelsize'] = MEDIUM_SIZE
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE
plt.rcParams['figure.titlesize'] = LARGE_SIZE
plt.rcParams['figure.figsize'] = [7.2, 7.2]
plt.rcParams['figure.dpi'] = 60
plt.rcParams['figure.facecolor'] = (1.0, 1.0, 1.0, 0.0)

from utils import SREQ, LREQ

# %%
x = np.arange(0, 14.1,0.1)
y = np.arange(0, 14.1,0.1)
ux, uy = np.meshgrid(x,y)
uz = ux**0.5 * uy**0.5
cx = np.arange(0, 12.1, 0.1)
cy = 12 - cx

fig, ax = plt.subplots()
CS = ax.contour(ux,uy,uz, levels=np.arange(4,13), cmap=cm.winter)
ax.clabel(CS, CS.levels, inline=True, fontsize=MEDIUM_SIZE)
ax.plot(cx,cy,color='black',linewidth=3)
#ax.plot(4,4,'^',color='black')
#ax.text(4.125,4,r'$32$',fontsize=MEDIUM_SIZE)
ax.set_ylabel(r'$y$')
ax.set_xlabel(r'$x$')
ax.set_axisbelow(True)
plt.grid(alpha=0.2)
plt.savefig('../assets/images/10-multivariate-optimization-2-example-1.png', bbox_inches='tight')
plt.show()

# %%
x = np.arange(0, 12.1,0.1)
y = np.arange(0, 12.1,0.1)
ux, uy = np.meshgrid(x,y)
uz = ux*uy
cx = np.arange(0, 12.1, 0.1)
cy = 6 - 0.5*cx

fig, ax = plt.subplots()
CS = ax.contour(ux,uy,uz, levels=np.arange(2,66,8), cmap=cm.winter)
ax.clabel(CS, CS.levels, inline=True, fontsize=MEDIUM_SIZE)
ax.plot(cx,cy,color='black',linewidth=3)
#ax.plot(4,4,'^',color='black')
#ax.text(4.125,4,r'$32$',fontsize=MEDIUM_SIZE)
ax.set_ylabel(r'$y$')
ax.set_xlabel(r'$x$')
ax.set_axisbelow(True)
ax.set_xticks(np.arange(0,13,1))
ax.set_yticks(np.arange(0,13,1))
plt.grid(alpha=0.2)
plt.savefig('../assets/images/10-multivariate-optimization-2-example-2.png', bbox_inches='tight')
plt.show()
