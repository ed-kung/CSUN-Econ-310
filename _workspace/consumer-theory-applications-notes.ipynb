# %%
import os
import numpy as np
import pandas as pd
from IPython.display import display, Markdown, Latex
import json
import utils2 as u2
from matplotlib import pyplot as plt

SMALL_SIZE = 14
MEDIUM_SIZE = 16
LARGE_SIZE = 18
HUGE_SIZE = 20

plt.rcdefaults()
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'Helvetica'
plt.rcParams['font.size'] = MEDIUM_SIZE
plt.rcParams['axes.titlesize'] = LARGE_SIZE
plt.rcParams['axes.labelsize'] = MEDIUM_SIZE
plt.rcParams['xtick.labelsize'] = MEDIUM_SIZE
plt.rcParams['ytick.labelsize'] = MEDIUM_SIZE
plt.rcParams['legend.fontsize'] = MEDIUM_SIZE
plt.rcParams['figure.titlesize'] = LARGE_SIZE
plt.rcParams['figure.figsize'] = [7.2, 7.2]
plt.rcParams['figure.dpi'] = 60
plt.rcParams['figure.facecolor'] = (1.0, 1.0, 1.0, 0.0)

IMAGE_PATH = "../assets/images/graphs"

rng = np.random.default_rng(111)

# %%
TYPE = "PriceChangeProblem"
params = {'x1': 5.0, 'px1': 3.0, 'py1': 1.0, 'x2': 45.0, 'px2': 1.0, 'py2': 1.0, 'I': 60, 'xunit': 5, 'xn': 13}
problem = u2.load_problem(TYPE, params)
print(problem.params)
display(Latex(problem.setup_list[0]['setup']))
u2.show_menu(TYPE)
problem.setup_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-applications-example-1-setup.png")
problem.solution_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-applications-example-1-solution.png")
# Out:
# {'x1': 5.0, 'px1': 3.0, 'py1': 1.0, 'x2': 45.0, 'px2': 1.0, 'py2': 1.0, 'I': 60, 'xunit': 5, 'xn': 13}
# A consumer with income \(I=60\) has utility over two goods, \(x\) and \(y\), shown by the indifference curves below.
# \begin{center}
# \includegraphics[width=3in]{generic_problem_setup.png}
# \end{center}
# The prices of the goods are initially \(p_x = 3\) and \(p_y = 1\). One day, the price of good \(x\) changes to \(p_x^\prime = 1\).
# {'x1': 7, 'px1': 1, 'py1': 1, 'x2': 8, 'px2': 1, 'py2': 2, 'I': 12, 'xunit': 1, 'xn': 13}
# {'y1': 5.0, 'y2': 2.0, 'price_that_changed': 'y', 'comp_or_sub': 'substitutes'}
# 0:  A consumer with income \(I=12\) has utility over two goods, \(x\) and \(y\), shown by the indifference curves below. \begin{center} \includegraphics[width=3in]{generic_problem_setup.png} \end{center} The prices of the goods are initially \(p_x = 1\) and \(p_y = 1\). One day, the price of good \(y\) changes to \(p_y^\prime = 2\).
#
# ...

# %%
TYPE = "PriceChangeProblem"
params = {'x1': 9.0, 'px1': 1.0, 'py1': 1.0, 'x2': 8.0, 'px2': 1.0, 'py2': 4.0, 'I': 12, 'xunit': 1, 'xn': 13}
problem = u2.load_problem(TYPE, params)
print(problem.params)
display(Latex(problem.setup_list[0]['setup']))
u2.show_menu(TYPE)
problem.setup_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-applications-example-2-setup.png")
problem.solution_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-applications-example-2-solution.png")
# Out:
# {'x1': 9.0, 'px1': 1.0, 'py1': 1.0, 'x2': 8.0, 'px2': 1.0, 'py2': 4.0, 'I': 12, 'xunit': 1, 'xn': 13}
# A consumer with income \(I=12\) has utility over two goods, \(x\) and \(y\), shown by the indifference curves below.
# \begin{center}
# \includegraphics[width=3in]{generic_problem_setup.png}
# \end{center}
# The prices of the goods are initially \(p_x = 1\) and \(p_y = 1\). One day, the price of good \(y\) changes to \(p_y^\prime = 4\).
# {'x1': 7, 'px1': 1, 'py1': 1, 'x2': 8, 'px2': 1, 'py2': 2, 'I': 12, 'xunit': 1, 'xn': 13}
# {'y1': 5.0, 'y2': 2.0, 'price_that_changed': 'y', 'comp_or_sub': 'substitutes'}
# 0:  A consumer with income \(I=12\) has utility over two goods, \(x\) and \(y\), shown by the indifference curves below. \begin{center} \includegraphics[width=3in]{generic_problem_setup.png} \end{center} The prices of the goods are initially \(p_x = 1\) and \(p_y = 1\). One day, the price of good \(y\) changes to \(p_y^\prime = 2\).
#
# ...

# %%
TYPE = "PublicSchoolProblem"
params = {'x_private': 20, 'x_public': 60, 'px': 15.0, 'py': 10.0, 'I': 1200, 'xunit': 10, 'xn': 13}
problem = u2.load_problem(TYPE, params)
print(problem.params)
display(Latex(problem.setup_list[0]['setup']))
problem.setup_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-applications-example-3-setup.png")
problem.solution_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-applications-example-3-solution.png")
# Out:
# {'x_private': 20, 'x_public': 60, 'px': 15.0, 'py': 10.0, 'I': 1200, 'xunit': 10, 'xn': 13}
# A family can spend their income on either education or other goods. The diagram below shows the family's budget constraint when only private school options are available, as well as their indifference curves over education and other consumption.
# \begin{center}
# \includegraphics[width=3in]{generic_problem_setup.png}
# \end{center}
# A public school option is also available which provides 60 units of education for free.
# (<Figure size 432x432 with 1 Axes>,
#  <Axes: xlabel='Education', ylabel='Other Goods'>)

# %%
TYPE = "PublicSchoolProblem"
params = {'x_private': 9, 'x_public': 4, 'px': 109.0909090909091, 'py': 109.0909090909091, 'I': 1200, 'xunit': 1, 'xn': 13}
problem = u2.load_problem(TYPE, params)
print(problem.params)
display(Latex(problem.setup_list[0]['setup']))
problem.setup_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-applications-example-4-setup.png")
problem.solution_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-applications-example-4-solution.png")
# Out:
# {'x_private': 9, 'x_public': 4, 'px': 109.0909090909091, 'py': 109.0909090909091, 'I': 1200, 'xunit': 1, 'xn': 13}
# A family can spend their income on either education or other goods. The diagram below shows the family's budget constraint when only private school options are available, as well as their indifference curves over education and other consumption.
# \begin{center}
# \includegraphics[width=3in]{generic_problem_setup.png}
# \end{center}
# A public school option is also available which provides 4 units of education for free.
# (<Figure size 432x432 with 1 Axes>,
#  <Axes: xlabel='Education', ylabel='Other Goods'>)

# %%
TYPE = "PublicSchoolProblem"
params = {'x_private': 30, 'x_public': 20, 'px': 15.0, 'py': 15.0, 'I': 1200, 'xunit': 10, 'xn': 13}
problem = u2.load_problem(TYPE, params)
print(problem.params)
display(Latex(problem.setup_list[0]['setup']))
problem.setup_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-applications-example-5-setup.png")
problem.solution_axis.draw(saveas=f"{IMAGE_PATH}/consumer-theory-applications-example-5-solution.png")
# Out:
# {'x_private': 30, 'x_public': 20, 'px': 15.0, 'py': 15.0, 'I': 1200, 'xunit': 10, 'xn': 13}
# A family can spend their income on either education or other goods. The diagram below shows the family's budget constraint when only private school options are available, as well as their indifference curves over education and other consumption.
# \begin{center}
# \includegraphics[width=3in]{generic_problem_setup.png}
# \end{center}
# A public school option is also available which provides 20 units of education for free.
# (<Figure size 432x432 with 1 Axes>,
#  <Axes: xlabel='Education', ylabel='Other Goods'>)

# %% [raw]
# df1 = df.loc[(df['choice']=='public') & (df['x_public']>df['x_private'])].sample(5,random_state=rng)
# df2 = df.loc[(df['choice']=='public') & (df['x_public']<df['x_private'])].sample(5,random_state=rng)
# df3 = df.loc[(df['choice']=='public') & (df['x_public']==df['x_private'])].sample(5,random_state=rng)
# df4 = df.loc[(df['choice']=='private')].sample(10,random_state=rng)

# %%
TYPE = "PublicSchoolProblem"
u2.show_menu(TYPE)
# Out:
# {'x_private': 6, 'x_public': 4, 'px': 1, 'py': 1, 'I': 12, 'xunit': 1, 'xn': 13}
# {'y_private': 6.0, 'U_private': 5.999999999999999, 'U_public': 6.928203230275509, 'choice': 'public', 'xchoice': 4, 'ychoice': 12.0}
# 0:  A family can spend their income on either education or other goods. The diagram below shows the family's budget constraint when only private school options are available, as well as their indifference curves over education and other consumption. \begin{center} \includegraphics[width=3in]{generic_problem_setup.png} \end{center} A public school option is also available which provides 4 units of education for free.
#
# 0: On the diagram, label the optimal private school option A and label the public school option B.
#
# 1: Which option offers higher utility, public or private?
#
# 2: Which option will the family choose?
#
# 3: If the public school option were removed, would this increase or decrease the amount of education consumed?
#
# ...
