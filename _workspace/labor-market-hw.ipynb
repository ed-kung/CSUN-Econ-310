# %%
import os
import numpy as np
import pandas as pd
from IPython.display import display, Markdown, Latex

import econtools
from econtools.documents import Homework, RawLatex
import utils2 as u2

OUTPUT_DIR = "./tex"
TITLE = "Labor Market Problem Set"
FILENAME = "labor-market-hw"

doc = Homework(
    title = TITLE,
)
rng = np.random.default_rng(104)

# %%
tex = fr"""
\begin{{q}}
Review, memorize, and be able to explain the ``big picture review'' section for this lecture.
\end{{q}}
"""
doc.add(RawLatex(tex))

# %%
tex = fr"""
\begin{{q}}
If the worker's disutility for work increases, what do you expect to happen to the equilibrium wage and quantity of labor supplied in the market?
\end{{q}}
"""
doc.add(RawLatex(tex))

# %%
tex = fr"""
\begin{{q}}
If the firm's productivity increases, what do you expect to happen to the equilibrium wage and quantity of labor supplied in the market?
\end{{q}}
"""
doc.add(RawLatex(tex))

# %%
TYPE = 'ExponentialLaborMarketProblem'
df = pd.read_csv(f"{TYPE}.csv")
params = dict(df.sample(1,random_state=rng).iloc[0])
problem = u2.load_problem(TYPE, params, rng=rng)
doc.add(u2.get_multipart_sa(problem,setup_id=0,question_ids=[0,1,2,3]))
print(problem.sol)
# Out:
# {'w': 6.928203230275509, 'L': 12.0, 'U': 27.712812921102042, 'profit': 83.13843876330611}

# %%
TYPE = 'ExponentialLaborMarketProblem'
df = pd.read_csv(f"{TYPE}.csv")
params = dict(df.sample(1,random_state=rng).iloc[0])
problem = u2.load_problem(TYPE, params, rng=rng)
doc.add(u2.get_multipart_sa(problem,setup_id=0,question_ids=[0,1,2,3]))
print(problem.sol)
# Out:
# {'w': 3.7416573867739418, 'L': 14.0, 'U': 17.461067804945067, 'profit': 52.38320341483517}

# %%
doc.print_pdf(FILENAME, OUTPUT_DIR)
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./labor-market-hw.tex
# LaTeX2e <2024-11-01> patch level 2
# L3 programming layer <2025-01-18>
# (/usr/local/texlive/2025/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2024/06/29 v1.4n Standard LaTeX document class
# (/usr/local/texlive/2025/texmf-dist/tex/latex/base/size11.clo))
# (/usr/local/texlive/2025/texmf-dist/tex/latex/base/inputenc.sty)
# (/usr/local/texlive/2025/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2025/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2025/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2025/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2025/texmf-dist/tex/latex/pgfplots/pgfplots.sty
# (/usr/local/texlive/2025/texmf-dist/tex/generic/pgfplots/pgfplots.revision.tex)
# ...
